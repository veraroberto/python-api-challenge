# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import json

from citipy import citipy


from config import gkey

# %%
cities_pd = pd.read_csv('Cities.csv')
cities_pd.head(20)
print(len(cities_pd
# Out:
# 92

# %%
temp_min = 70
temp_max = 80

city_temp_max = cities_pd.loc[ cities_pd['Temperature'] <temp_max,:]

city_temp = city_temp_max.loc[temp_min>= city_temp_max['Temperature'],:]
cities_temp = city_temp.reset_index()
cities_temp
citie
# Out:
#     index                     City  Temperature  Latitude  Longitude  \
# 0       0                   Castro        54.91  -24.7911   -50.0119
# 1       4                   Torbay        39.87   47.6666   -52.7314
# 2       6               Bredasdorp        57.20  -34.5322    20.0403
# 3       8                  Iqaluit        21.09   63.7506   -68.5145
# 4       9          Haines Junction        50.00   60.7522  -137.5108
# 5      10                  Ushuaia        42.80  -54.8000   -68.3000
# 6      12               Bredasdorp        57.20  -34.5322    20.0403
# 7      13                  Ahipara        63.09  -35.1667   173.1667
# 8      14                Jamestown        44.69   42.0970   -79.2353
# 9      15                   Kozhva        39.11   65.1073    57.0459
# 10     16                  Ushuaia        42.80  -54.8000   -68.3000
# 11     21           Ribeira Grande        60.57   38.5167   -28.7000
# 12     22                   Beidao        62.78   34.5686   105.8933
# ...
